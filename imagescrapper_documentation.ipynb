# %% [markdown]
#                                 *IMAGE SCRAPPING ASSIGNMENT*

# %% [markdown]
# 1.	In jupyter notebook, create img_scrape.ipynb file. Import all the required libraries. Download chromedriver.exe for windows and save in the same directory.

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/img_scrap_1.png")

# %% [markdown]
# 2.	Define all the required functions to scrap the images from the browser.

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/img_scrap_2.png")

# %% [markdown]
# 3.	Other functions for image scrapping:

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/img_scrap_3.png")

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/img_scrap_4.png")

# %% [markdown]
# 4.	After running all the functions, the images are downloaded to the desired location.

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/img_scrap_5.png")

# %% [markdown]
# 5.	Installation in PyCharm:

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/imagescrapper_1.png")

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/imagescrapper_2.png")

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/imagescrapper_3.png")

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/imagescrapper_4.png")

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/imagescrapper_5.png")

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/imagescrapper_6.png")

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/imagescrapper_7.png")

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/imagescrapper_8.png")

# %% [markdown]
# 6.	Results.html:

# %%
from IPython.display import Image
Image(filename="C:/Users/Sreenivasan/Desktop/image_scrapper_assignment/img_scrap_output.png")
